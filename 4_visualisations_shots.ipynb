# %% [markdown]
# <a href="https://colab.research.google.com/github/Macgie29/FootballAnalytics/blob/main/4_visualisations_shots.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import matplotlib.pyplot as plt
import numpy as np
from mplsoccer import Pitch, Sbopen, VerticalPitch

# %%
parser = Sbopen()
df, related, freeze, tactics = parser.event(69301)
#get team names
team1, team2 = df.team_name.unique()
#A dataframe of shots
shots = df.loc[df['type_name'] == 'Shot'].set_index('id')

# %%
shots.head()
# Out:
#                                       index  period        timestamp  minute  \
# id
# f158cbc0-a7a1-4787-8f73-15c66ae55764    340       1  00:10:24.396000      10
# de5c41c5-9200-439e-b051-bfe2016d689a    531       1  00:15:28.174000      15
# 106faebb-00bc-4453-b1c1-1bacdb1ebbc5    720       1  00:21:08.216000      21
# 309f6f06-3977-49ac-8c0b-0e31b54404ed    742       1  00:22:46.449000      22
# d1c8dbc7-a164-4e34-8674-1eeba842cbbd    956       1  00:30:38.174000      30
#
#                                       second  possession  duration  match_id  \
# id
# f158cbc0-a7a1-4787-8f73-15c66ae55764      24          18  1.342346     69301
# de5c41c5-9200-439e-b051-bfe2016d689a      28          25  0.472900     69301
# 106faebb-00bc-4453-b1c1-1bacdb1ebbc5       8          35  1.254112     69301
# 309f6f06-3977-49ac-8c0b-0e31b54404ed      46          37  1.118733     69301
# d1c8dbc7-a164-4e34-8674-1eeba842cbbd      38          52  1.359400     69301
#
#                                       type_id type_name  ...  \
# id                                                       ...
# f158cbc0-a7a1-4787-8f73-15c66ae55764       16      Shot  ...
# de5c41c5-9200-439e-b051-bfe2016d689a       16      Shot  ...
# 106faebb-00bc-4453-b1c1-1bacdb1ebbc5       16      Shot  ...
# 309f6f06-3977-49ac-8c0b-0e31b54404ed       16      Shot  ...
# d1c8dbc7-a164-4e34-8674-1eeba842cbbd       16      Shot  ...
#
#                                       block_deflection pass_cut_back  \
# id
# f158cbc0-a7a1-4787-8f73-15c66ae55764               NaN           NaN
# de5c41c5-9200-439e-b051-bfe2016d689a               NaN           NaN
# 106faebb-00bc-4453-b1c1-1bacdb1ebbc5               NaN           NaN
# 309f6f06-3977-49ac-8c0b-0e31b54404ed               NaN           NaN
# d1c8dbc7-a164-4e34-8674-1eeba842cbbd               NaN           NaN
#
#                                       bad_behaviour_card_id  \
# id
# f158cbc0-a7a1-4787-8f73-15c66ae55764                    NaN
# de5c41c5-9200-439e-b051-bfe2016d689a                    NaN
# 106faebb-00bc-4453-b1c1-1bacdb1ebbc5                    NaN
# 309f6f06-3977-49ac-8c0b-0e31b54404ed                    NaN
# d1c8dbc7-a164-4e34-8674-1eeba842cbbd                    NaN
#
#                                      bad_behaviour_card_name  pass_no_touch  \
# id
# f158cbc0-a7a1-4787-8f73-15c66ae55764                     NaN            NaN
# de5c41c5-9200-439e-b051-bfe2016d689a                     NaN            NaN
# 106faebb-00bc-4453-b1c1-1bacdb1ebbc5                     NaN            NaN
# 309f6f06-3977-49ac-8c0b-0e31b54404ed                     NaN            NaN
# d1c8dbc7-a164-4e34-8674-1eeba842cbbd                     NaN            NaN
#
#                                      block_save_block  \
# id
# f158cbc0-a7a1-4787-8f73-15c66ae55764              NaN
# de5c41c5-9200-439e-b051-bfe2016d689a              NaN
# 106faebb-00bc-4453-b1c1-1bacdb1ebbc5              NaN
# 309f6f06-3977-49ac-8c0b-0e31b54404ed              NaN
# d1c8dbc7-a164-4e34-8674-1eeba842cbbd              NaN
#
#                                       foul_committed_advantage  \
# id
# f158cbc0-a7a1-4787-8f73-15c66ae55764                       NaN
# de5c41c5-9200-439e-b051-bfe2016d689a                       NaN
# 106faebb-00bc-4453-b1c1-1bacdb1ebbc5                       NaN
# 309f6f06-3977-49ac-8c0b-0e31b54404ed                       NaN
# d1c8dbc7-a164-4e34-8674-1eeba842cbbd                       NaN
#
#                                       foul_won_advantage  \
# id
# f158cbc0-a7a1-4787-8f73-15c66ae55764                 NaN
# de5c41c5-9200-439e-b051-bfe2016d689a                 NaN
# 106faebb-00bc-4453-b1c1-1bacdb1ebbc5                 NaN
# 309f6f06-3977-49ac-8c0b-0e31b54404ed                 NaN
# d1c8dbc7-a164-4e34-8674-1eeba842cbbd                 NaN
#
#                                      foul_committed_card_id  \
# id
# f158cbc0-a7a1-4787-8f73-15c66ae55764                    NaN
# de5c41c5-9200-439e-b051-bfe2016d689a                    NaN
# 106faebb-00bc-4453-b1c1-1bacdb1ebbc5                    NaN
# 309f6f06-3977-49ac-8c0b-0e31b54404ed                    NaN
# d1c8dbc7-a164-4e34-8674-1eeba842cbbd                    NaN
#
#                                       foul_committed_card_name
# id
# f158cbc0-a7a1-4787-8f73-15c66ae55764                       NaN
# de5c41c5-9200-439e-b051-bfe2016d689a                       NaN
# 106faebb-00bc-4453-b1c1-1bacdb1ebbc5                       NaN
# 309f6f06-3977-49ac-8c0b-0e31b54404ed                       NaN
# d1c8dbc7-a164-4e34-8674-1eeba842cbbd                       NaN
#
# [5 rows x 73 columns]

# %%
shots.columns
# Out:
# Index(['index', 'period', 'timestamp', 'minute', 'second', 'possession',
#        'duration', 'match_id', 'type_id', 'type_name', 'possession_team_id',
#        'possession_team_name', 'play_pattern_id', 'play_pattern_name',
#        'team_id', 'team_name', 'tactics_formation', 'player_id', 'player_name',
#        'position_id', 'position_name', 'pass_recipient_id',
#        'pass_recipient_name', 'pass_length', 'pass_angle', 'pass_height_id',
#        'pass_height_name', 'end_x', 'end_y', 'body_part_id', 'body_part_name',
#        'sub_type_id', 'sub_type_name', 'x', 'y', 'under_pressure',
#        'outcome_id', 'outcome_name', 'out', 'counterpress', 'pass_deflected',
#        'pass_switch', 'technique_id', 'technique_name', 'pass_cross',
#        'off_camera', 'shot_statsbomb_xg', 'end_z', 'shot_first_time',
#        'goalkeeper_position_id', 'goalkeeper_position_name',
#        'ball_recovery_recovery_failure', 'pass_assisted_shot_id',
#        'pass_shot_assist', 'shot_key_pass_id', 'foul_won_defensive',
#        'aerial_won', 'pass_goal_assist', 'substitution_replacement_id',
#        'substitution_replacement_name', 'foul_committed_offensive',
#        'shot_one_on_one', 'dribble_overrun', 'block_deflection',
#        'pass_cut_back', 'bad_behaviour_card_id', 'bad_behaviour_card_name',
#        'pass_no_touch', 'block_save_block', 'foul_committed_advantage',
#        'foul_won_advantage', 'foul_committed_card_id',
#        'foul_committed_card_name'],
#       dtype='object')

# %%
pitch = Pitch(line_color = "black")
fig, ax = pitch.draw(figsize=(10, 7))
#Size of the pitch in yards (!!!)
pitchLengthX = 120
pitchWidthY = 80
#Plot the shots by looping through them.
for i,shot in shots.iterrows():
    #get the information
    x=shot['x']
    y=shot['y']
    goal=shot['outcome_name']=='Goal'
    team_name=shot['team_name']
    #set circlesize
    circleSize=2
    #plot England
    if (team_name==team1):
        if goal:
            shotCircle=plt.Circle((x,y),circleSize,color="red")
            plt.text(x+1,y-2,shot['player_name'])
        else:
            shotCircle=plt.Circle((x,y),circleSize,color="red")
            shotCircle.set_alpha(.2)
    #plot Sweden
    else:
        if goal:
            shotCircle=plt.Circle((pitchLengthX-x,pitchWidthY - y),circleSize,color="blue")
            plt.text(pitchLengthX-x+1,pitchWidthY - y - 2 ,shot['player_name'])
        else:
            shotCircle=plt.Circle((pitchLengthX-x,pitchWidthY - y),circleSize,color="blue")
            shotCircle.set_alpha(.2)
    ax.add_patch(shotCircle)
#set title
fig.suptitle("England (red) and Sweden (blue) shots", fontsize = 24)
fig.set_size_inches(10, 7)
plt.show()

# %%
#create pitch
pitch = Pitch(line_color='black')
fig, ax = pitch.grid(grid_height=0.9, title_height=0.06, axis=False,
                     endnote_height=0.04, title_space=0, endnote_space=0)
#query
mask_england = (df.type_name == 'Shot') & (df.team_name == team1)
#finding rows in the df and keeping only necessary columns
df_england = df.loc[mask_england, ['x', 'y', 'outcome_name', "player_name"]]

#plot them - if shot ended with Goal - alpha 1 and add name
#for England
for i, row in df_england.iterrows():
    if row["outcome_name"] == 'Goal':
    #make circle
       pitch.scatter(row.x, row.y, alpha = 1, s = 500, color = "red", ax=ax['pitch'])
       pitch.annotate(row["player_name"], (row.x + 1, row.y - 2), ax=ax['pitch'], fontsize = 12)
    else:
       pitch.scatter(row.x, row.y, alpha = 0.2, s = 500, color = "red", ax=ax['pitch'])

mask_sweden = (df.type_name == 'Shot') & (df.team_name == team2)
df_sweden = df.loc[mask_sweden, ['x', 'y', 'outcome_name', "player_name"]]

#for Sweden we need to revert coordinates
for i, row in df_sweden.iterrows():
    if row["outcome_name"] == 'Goal':
       pitch.scatter(120 - row.x, 80 - row.y, alpha = 1, s = 500, color = "blue", ax=ax['pitch'])
       pitch.annotate(row["player_name"], (120 - row.x + 1, 80 - row.y - 2), ax=ax['pitch'], fontsize = 12)
    else:
       pitch.scatter(120 - row.x, 80 - row.y, alpha = 0.2, s = 500, color = "blue", ax=ax['pitch'])

fig.suptitle("England (red) and Sweden (blue) shots", fontsize = 30)
plt.show()

# %%
pitch = VerticalPitch(line_color='black', half = True)
fig, ax = pitch.grid(grid_height=0.9, title_height=0.06, axis=False,
                     endnote_height=0.04, title_space=0, endnote_space=0)
#plotting all shots
pitch.scatter(df_england.x, df_england.y, alpha = 1, s = 500, color = "red", ax=ax['pitch'], edgecolors="black")
fig.suptitle("England shots against Sweden", fontsize = 30)
plt.show()

# %%
#Plotting Passes

parser = Sbopen()
df, related, freeze, tactics = parser.event(69301)
#get team names
team1, team2 = df.team_name.unique()
#A dataframe of shots
passes = df.loc[df['type_name'] == 'Pass'].set_index('id')

pitch = Pitch(line_color = "black")
fig, ax = pitch.draw(figsize=(10, 7))
#Size of the pitch in yards (!!!)
pitchLengthX = 120
pitchWidthY = 80
#Plot the shots by looping through them.
for i,pass_ in passes.iterrows():
    #get the information
    x=pass_['x']
    y=pass_['y']
    team_name=pass_['team_name']
    #set circlesize
    circleSize=2
    #plot England
    if (team_name==team1):
        passCircle=plt.Circle((x,y),circleSize,color="red")
        passCircle.set_alpha(.2)
    #plot Sweden
    else:
        passCircle=plt.Circle((pitchLengthX-x,pitchWidthY - y),circleSize,color="blue")
        passCircle.set_alpha(.2)
    ax.add_patch(passCircle)
#set title
fig.suptitle("England (red) and Sweden (blue) passes", fontsize = 24)
fig.set_size_inches(10, 7)
plt.show()

# %%
passes.player_name.head()
# Out:
# id
# 760528a6-2de2-427f-9795-b2b19819ef1f        Ellen White
# ecec23b8-f03d-4bee-80df-9fabec558187    Francesca Kirby
# bdedb943-ddac-42ab-bc8b-756faa49d9e6        Lucy Bronze
# 456a1ae6-1fe8-4ffc-952b-152a7f89e1d2      Nikita Parris
# a8d0155f-260c-4470-b842-b474ea58ffa7         Jill Scott
# Name: player_name, dtype: object

# %%
#Plotting Passes

parser = Sbopen()
df, related, freeze, tactics = parser.event(69301)
#get team names
team1, team2 = df.team_name.unique()
#A dataframe of shots
passes = df.loc[(df['type_name'] == 'Pass') & (df['player_name'] == 'Sara Caroline Seger')].set_index('id')

pitch = Pitch(line_color = "black")
fig, ax = pitch.draw(figsize=(10, 7))
#Size of the pitch in yards (!!!)
pitchLengthX = 120
pitchWidthY = 80
#Plot the shots by looping through them.
for i,pass_ in passes.iterrows():
    #get the information
    x=pass_['x']
    y=pass_['y']
    team_name=pass_['team_name']
    #set circlesize
    circleSize=2
    #plot England
    if (team_name==team1):
        passCircle=plt.Circle((x,y),circleSize,color="red")
        passCircle.set_alpha(.2)
    #plot Sweden
    else:
        passCircle=plt.Circle((pitchLengthX-x,pitchWidthY - y),circleSize,color="blue")
        passCircle.set_alpha(.2)
    ax.add_patch(passCircle)
#set title
fig.suptitle("England (red) and Sweden (blue) passes", fontsize = 24)
fig.set_size_inches(10, 7)
plt.show()

# %%
pitch = Pitch(line_color = "black")
fig, ax = pitch.draw(figsize=(10, 7))
#Size of the pitch in yards (!!!)
pitchLengthX = 120
pitchWidthY = 80
#Plot the shots by looping through them.
for i,shot in shots.iterrows():
   print(i)
# Out:
# f158cbc0-a7a1-4787-8f73-15c66ae55764
# de5c41c5-9200-439e-b051-bfe2016d689a
# 106faebb-00bc-4453-b1c1-1bacdb1ebbc5
# 309f6f06-3977-49ac-8c0b-0e31b54404ed
# d1c8dbc7-a164-4e34-8674-1eeba842cbbd
# 38ac2346-ce1d-4d7a-9dcc-39d337eebede
# 7f6c533d-e8d4-4810-8be6-e3183e3caea1
# 79e0c6d1-9640-420a-8ba8-d0304b1f24fa
# 9a3c4fba-3223-4305-a06b-e08f52796c34
# cb2480d3-d896-4568-9fb5-d0a4d1a70ddd
# d3c5e620-8fa9-4c0b-8fd8-a6c95463c53b
# 300ca316-03cf-4aa1-b12c-68d91ffb6f1e
# 9fe6251c-6b05-4f27-bcda-2042f7dce864
# 8ea1599d-6dc6-4e00-8d51-2f28f41a3d6f
# 9c5e8a81-051b-440b-9aad-dd704587ee30
# 435009e3-0653-45e3-95f6-f4215613adab
# d68b860f-d159-4a6f-b53f-b49b024c9399
# ee3a7d47-de33-4a21-9dc1-927571c52729
# 1b0b67f2-c8aa-4286-a0a6-58bf0389c5a0

# %%
shots
# Out:
#                                       index  period        timestamp  minute  \
# id
# f158cbc0-a7a1-4787-8f73-15c66ae55764    340       1  00:10:24.396000      10
# de5c41c5-9200-439e-b051-bfe2016d689a    531       1  00:15:28.174000      15
# 106faebb-00bc-4453-b1c1-1bacdb1ebbc5    720       1  00:21:08.216000      21
# 309f6f06-3977-49ac-8c0b-0e31b54404ed    742       1  00:22:46.449000      22
# d1c8dbc7-a164-4e34-8674-1eeba842cbbd    956       1  00:30:38.174000      30
# 38ac2346-ce1d-4d7a-9dcc-39d337eebede   1327       1  00:43:53.832000      43
# 7f6c533d-e8d4-4810-8be6-e3183e3caea1   1485       1  00:48:48.810000      48
# 79e0c6d1-9640-420a-8ba8-d0304b1f24fa   1577       1  00:50:54.516000      50
# 9a3c4fba-3223-4305-a06b-e08f52796c34   1783       2  00:04:49.997000      49
# cb2480d3-d896-4568-9fb5-d0a4d1a70ddd   1795       2  00:04:55.985000      49
# d3c5e620-8fa9-4c0b-8fd8-a6c95463c53b   2012       2  00:11:48.692000      56
# 300ca316-03cf-4aa1-b12c-68d91ffb6f1e   2205       2  00:16:32.408000      61
# 9fe6251c-6b05-4f27-bcda-2042f7dce864   2262       2  00:18:35.122000      63
# 8ea1599d-6dc6-4e00-8d51-2f28f41a3d6f   2326       2  00:20:50.777000      65
# 9c5e8a81-051b-440b-9aad-dd704587ee30   2962       2  00:37:19.021000      82
# 435009e3-0653-45e3-95f6-f4215613adab   3094       2  00:42:29.326000      87
# d68b860f-d159-4a6f-b53f-b49b024c9399   3120       2  00:44:02.250000      89
# ee3a7d47-de33-4a21-9dc1-927571c52729   3169       2  00:45:17.335000      90
# 1b0b67f2-c8aa-4286-a0a6-58bf0389c5a0   3197       2  00:45:56.103000      90
#
#                                       second  possession  duration  match_id  \
# id
# f158cbc0-a7a1-4787-8f73-15c66ae55764      24          18  1.342346     69301
# de5c41c5-9200-439e-b051-bfe2016d689a      28          25  0.472900     69301
# 106faebb-00bc-4453-b1c1-1bacdb1ebbc5       8          35  1.254112     69301
# 309f6f06-3977-49ac-8c0b-0e31b54404ed      46          37  1.118733     69301
# d1c8dbc7-a164-4e34-8674-1eeba842cbbd      38          52  1.359400     69301
# 38ac2346-ce1d-4d7a-9dcc-39d337eebede      53          75  1.828469     69301
# 7f6c533d-e8d4-4810-8be6-e3183e3caea1      48          83  2.337809     69301
# 79e0c6d1-9640-420a-8ba8-d0304b1f24fa      54          88  0.454200     69301
# 9a3c4fba-3223-4305-a06b-e08f52796c34      49         102  0.515500     69301
# cb2480d3-d896-4568-9fb5-d0a4d1a70ddd      55         102  1.399900     69301
# d3c5e620-8fa9-4c0b-8fd8-a6c95463c53b      48         117  0.222300     69301
# 300ca316-03cf-4aa1-b12c-68d91ffb6f1e      32         126  1.311600     69301
# 9fe6251c-6b05-4f27-bcda-2042f7dce864      35         132  4.693700     69301
# 8ea1599d-6dc6-4e00-8d51-2f28f41a3d6f      50         138  0.821417     69301
# 9c5e8a81-051b-440b-9aad-dd704587ee30      19         172  1.717500     69301
# 435009e3-0653-45e3-95f6-f4215613adab      29         181  0.901313     69301
# d68b860f-d159-4a6f-b53f-b49b024c9399       2         189  0.502900     69301
# ee3a7d47-de33-4a21-9dc1-927571c52729      17         191  1.339000     69301
# 1b0b67f2-c8aa-4286-a0a6-58bf0389c5a0      56         193  0.382200     69301
#
#                                       type_id type_name  ...  \
# id                                                       ...
# f158cbc0-a7a1-4787-8f73-15c66ae55764       16      Shot  ...
# de5c41c5-9200-439e-b051-bfe2016d689a       16      Shot  ...
# 106faebb-00bc-4453-b1c1-1bacdb1ebbc5       16      Shot  ...
# 309f6f06-3977-49ac-8c0b-0e31b54404ed       16      Shot  ...
# d1c8dbc7-a164-4e34-8674-1eeba842cbbd       16      Shot  ...
# 38ac2346-ce1d-4d7a-9dcc-39d337eebede       16      Shot  ...
# 7f6c533d-e8d4-4810-8be6-e3183e3caea1       16      Shot  ...
# 79e0c6d1-9640-420a-8ba8-d0304b1f24fa       16      Shot  ...
# 9a3c4fba-3223-4305-a06b-e08f52796c34       16      Shot  ...
# cb2480d3-d896-4568-9fb5-d0a4d1a70ddd       16      Shot  ...
# d3c5e620-8fa9-4c0b-8fd8-a6c95463c53b       16      Shot  ...
# 300ca316-03cf-4aa1-b12c-68d91ffb6f1e       16      Shot  ...
# 9fe6251c-6b05-4f27-bcda-2042f7dce864       16      Shot  ...
# 8ea1599d-6dc6-4e00-8d51-2f28f41a3d6f       16      Shot  ...
# 9c5e8a81-051b-440b-9aad-dd704587ee30       16      Shot  ...
# 435009e3-0653-45e3-95f6-f4215613adab       16      Shot  ...
# d68b860f-d159-4a6f-b53f-b49b024c9399       16      Shot  ...
# ee3a7d47-de33-4a21-9dc1-927571c52729       16      Shot  ...
# 1b0b67f2-c8aa-4286-a0a6-58bf0389c5a0       16      Shot  ...
#
#                                       block_deflection pass_cut_back  \
# id
# f158cbc0-a7a1-4787-8f73-15c66ae55764               NaN           NaN
# de5c41c5-9200-439e-b051-bfe2016d689a               NaN           NaN
# 106faebb-00bc-4453-b1c1-1bacdb1ebbc5               NaN           NaN
# 309f6f06-3977-49ac-8c0b-0e31b54404ed               NaN           NaN
# d1c8dbc7-a164-4e34-8674-1eeba842cbbd               NaN           NaN
# 38ac2346-ce1d-4d7a-9dcc-39d337eebede               NaN           NaN
# 7f6c533d-e8d4-4810-8be6-e3183e3caea1               NaN           NaN
# 79e0c6d1-9640-420a-8ba8-d0304b1f24fa               NaN           NaN
# 9a3c4fba-3223-4305-a06b-e08f52796c34               NaN           NaN
# cb2480d3-d896-4568-9fb5-d0a4d1a70ddd               NaN           NaN
# d3c5e620-8fa9-4c0b-8fd8-a6c95463c53b               NaN           NaN
# 300ca316-03cf-4aa1-b12c-68d91ffb6f1e               NaN           NaN
# 9fe6251c-6b05-4f27-bcda-2042f7dce864               NaN           NaN
# 8ea1599d-6dc6-4e00-8d51-2f28f41a3d6f               NaN           NaN
# 9c5e8a81-051b-440b-9aad-dd704587ee30               NaN           NaN
# 435009e3-0653-45e3-95f6-f4215613adab               NaN           NaN
# d68b860f-d159-4a6f-b53f-b49b024c9399               NaN           NaN
# ee3a7d47-de33-4a21-9dc1-927571c52729               NaN           NaN
# 1b0b67f2-c8aa-4286-a0a6-58bf0389c5a0               NaN           NaN
#
#                                       bad_behaviour_card_id  \
# id
# f158cbc0-a7a1-4787-8f73-15c66ae55764                    NaN
# de5c41c5-9200-439e-b051-bfe2016d689a                    NaN
# 106faebb-00bc-4453-b1c1-1bacdb1ebbc5                    NaN
# 309f6f06-3977-49ac-8c0b-0e31b54404ed                    NaN
# d1c8dbc7-a164-4e34-8674-1eeba842cbbd                    NaN
# 38ac2346-ce1d-4d7a-9dcc-39d337eebede                    NaN
# 7f6c533d-e8d4-4810-8be6-e3183e3caea1                    NaN
# 79e0c6d1-9640-420a-8ba8-d0304b1f24fa                    NaN
# 9a3c4fba-3223-4305-a06b-e08f52796c34                    NaN
# cb2480d3-d896-4568-9fb5-d0a4d1a70ddd                    NaN
# d3c5e620-8fa9-4c0b-8fd8-a6c95463c53b                    NaN
# 300ca316-03cf-4aa1-b12c-68d91ffb6f1e                    NaN
# 9fe6251c-6b05-4f27-bcda-2042f7dce864                    NaN
# 8ea1599d-6dc6-4e00-8d51-2f28f41a3d6f                    NaN
# 9c5e8a81-051b-440b-9aad-dd704587ee30                    NaN
# 435009e3-0653-45e3-95f6-f4215613adab                    NaN
# d68b860f-d159-4a6f-b53f-b49b024c9399                    NaN
# ee3a7d47-de33-4a21-9dc1-927571c52729                    NaN
# 1b0b67f2-c8aa-4286-a0a6-58bf0389c5a0                    NaN
#
#                                      bad_behaviour_card_name  pass_no_touch  \
# id
# f158cbc0-a7a1-4787-8f73-15c66ae55764                     NaN            NaN
# de5c41c5-9200-439e-b051-bfe2016d689a                     NaN            NaN
# 106faebb-00bc-4453-b1c1-1bacdb1ebbc5                     NaN            NaN
# 309f6f06-3977-49ac-8c0b-0e31b54404ed                     NaN            NaN
# d1c8dbc7-a164-4e34-8674-1eeba842cbbd                     NaN            NaN
# 38ac2346-ce1d-4d7a-9dcc-39d337eebede                     NaN            NaN
# 7f6c533d-e8d4-4810-8be6-e3183e3caea1                     NaN            NaN
# 79e0c6d1-9640-420a-8ba8-d0304b1f24fa                     NaN            NaN
# 9a3c4fba-3223-4305-a06b-e08f52796c34                     NaN            NaN
# cb2480d3-d896-4568-9fb5-d0a4d1a70ddd                     NaN            NaN
# d3c5e620-8fa9-4c0b-8fd8-a6c95463c53b                     NaN            NaN
# 300ca316-03cf-4aa1-b12c-68d91ffb6f1e                     NaN            NaN
# 9fe6251c-6b05-4f27-bcda-2042f7dce864                     NaN            NaN
# 8ea1599d-6dc6-4e00-8d51-2f28f41a3d6f                     NaN            NaN
# 9c5e8a81-051b-440b-9aad-dd704587ee30                     NaN            NaN
# 435009e3-0653-45e3-95f6-f4215613adab                     NaN            NaN
# d68b860f-d159-4a6f-b53f-b49b024c9399                     NaN            NaN
# ee3a7d47-de33-4a21-9dc1-927571c52729                     NaN            NaN
# 1b0b67f2-c8aa-4286-a0a6-58bf0389c5a0                     NaN            NaN
#
#                                      block_save_block  \
# id
# f158cbc0-a7a1-4787-8f73-15c66ae55764              NaN
# de5c41c5-9200-439e-b051-bfe2016d689a              NaN
# 106faebb-00bc-4453-b1c1-1bacdb1ebbc5              NaN
# 309f6f06-3977-49ac-8c0b-0e31b54404ed              NaN
# d1c8dbc7-a164-4e34-8674-1eeba842cbbd              NaN
# 38ac2346-ce1d-4d7a-9dcc-39d337eebede              NaN
# 7f6c533d-e8d4-4810-8be6-e3183e3caea1              NaN
# 79e0c6d1-9640-420a-8ba8-d0304b1f24fa              NaN
# 9a3c4fba-3223-4305-a06b-e08f52796c34              NaN
# cb2480d3-d896-4568-9fb5-d0a4d1a70ddd              NaN
# d3c5e620-8fa9-4c0b-8fd8-a6c95463c53b              NaN
# 300ca316-03cf-4aa1-b12c-68d91ffb6f1e              NaN
# 9fe6251c-6b05-4f27-bcda-2042f7dce864              NaN
# 8ea1599d-6dc6-4e00-8d51-2f28f41a3d6f              NaN
# 9c5e8a81-051b-440b-9aad-dd704587ee30              NaN
# 435009e3-0653-45e3-95f6-f4215613adab              NaN
# d68b860f-d159-4a6f-b53f-b49b024c9399              NaN
# ee3a7d47-de33-4a21-9dc1-927571c52729              NaN
# 1b0b67f2-c8aa-4286-a0a6-58bf0389c5a0              NaN
#
#                                       foul_committed_advantage  \
# id
# f158cbc0-a7a1-4787-8f73-15c66ae55764                       NaN
# de5c41c5-9200-439e-b051-bfe2016d689a                       NaN
# 106faebb-00bc-4453-b1c1-1bacdb1ebbc5                       NaN
# 309f6f06-3977-49ac-8c0b-0e31b54404ed                       NaN
# d1c8dbc7-a164-4e34-8674-1eeba842cbbd                       NaN
# 38ac2346-ce1d-4d7a-9dcc-39d337eebede                       NaN
# 7f6c533d-e8d4-4810-8be6-e3183e3caea1                       NaN
# 79e0c6d1-9640-420a-8ba8-d0304b1f24fa                       NaN
# 9a3c4fba-3223-4305-a06b-e08f52796c34                       NaN
# cb2480d3-d896-4568-9fb5-d0a4d1a70ddd                       NaN
# d3c5e620-8fa9-4c0b-8fd8-a6c95463c53b                       NaN
# 300ca316-03cf-4aa1-b12c-68d91ffb6f1e                       NaN
# 9fe6251c-6b05-4f27-bcda-2042f7dce864                       NaN
# 8ea1599d-6dc6-4e00-8d51-2f28f41a3d6f                       NaN
# 9c5e8a81-051b-440b-9aad-dd704587ee30                       NaN
# 435009e3-0653-45e3-95f6-f4215613adab                       NaN
# d68b860f-d159-4a6f-b53f-b49b024c9399                       NaN
# ee3a7d47-de33-4a21-9dc1-927571c52729                       NaN
# 1b0b67f2-c8aa-4286-a0a6-58bf0389c5a0                       NaN
#
#                                       foul_won_advantage  \
# id
# f158cbc0-a7a1-4787-8f73-15c66ae55764                 NaN
# de5c41c5-9200-439e-b051-bfe2016d689a                 NaN
# 106faebb-00bc-4453-b1c1-1bacdb1ebbc5                 NaN
# 309f6f06-3977-49ac-8c0b-0e31b54404ed                 NaN
# d1c8dbc7-a164-4e34-8674-1eeba842cbbd                 NaN
# 38ac2346-ce1d-4d7a-9dcc-39d337eebede                 NaN
# 7f6c533d-e8d4-4810-8be6-e3183e3caea1                 NaN
# 79e0c6d1-9640-420a-8ba8-d0304b1f24fa                 NaN
# 9a3c4fba-3223-4305-a06b-e08f52796c34                 NaN
# cb2480d3-d896-4568-9fb5-d0a4d1a70ddd                 NaN
# d3c5e620-8fa9-4c0b-8fd8-a6c95463c53b                 NaN
# 300ca316-03cf-4aa1-b12c-68d91ffb6f1e                 NaN
# 9fe6251c-6b05-4f27-bcda-2042f7dce864                 NaN
# 8ea1599d-6dc6-4e00-8d51-2f28f41a3d6f                 NaN
# 9c5e8a81-051b-440b-9aad-dd704587ee30                 NaN
# 435009e3-0653-45e3-95f6-f4215613adab                 NaN
# d68b860f-d159-4a6f-b53f-b49b024c9399                 NaN
# ee3a7d47-de33-4a21-9dc1-927571c52729                 NaN
# 1b0b67f2-c8aa-4286-a0a6-58bf0389c5a0                 NaN
#
#                                      foul_committed_card_id  \
# id
# f158cbc0-a7a1-4787-8f73-15c66ae55764                    NaN
# de5c41c5-9200-439e-b051-bfe2016d689a                    NaN
# 106faebb-00bc-4453-b1c1-1bacdb1ebbc5                    NaN
# 309f6f06-3977-49ac-8c0b-0e31b54404ed                    NaN
# d1c8dbc7-a164-4e34-8674-1eeba842cbbd                    NaN
# 38ac2346-ce1d-4d7a-9dcc-39d337eebede                    NaN
# 7f6c533d-e8d4-4810-8be6-e3183e3caea1                    NaN
# 79e0c6d1-9640-420a-8ba8-d0304b1f24fa                    NaN
# 9a3c4fba-3223-4305-a06b-e08f52796c34                    NaN
# cb2480d3-d896-4568-9fb5-d0a4d1a70ddd                    NaN
# d3c5e620-8fa9-4c0b-8fd8-a6c95463c53b                    NaN
# 300ca316-03cf-4aa1-b12c-68d91ffb6f1e                    NaN
# 9fe6251c-6b05-4f27-bcda-2042f7dce864                    NaN
# 8ea1599d-6dc6-4e00-8d51-2f28f41a3d6f                    NaN
# 9c5e8a81-051b-440b-9aad-dd704587ee30                    NaN
# 435009e3-0653-45e3-95f6-f4215613adab                    NaN
# d68b860f-d159-4a6f-b53f-b49b024c9399                    NaN
# ee3a7d47-de33-4a21-9dc1-927571c52729                    NaN
# 1b0b67f2-c8aa-4286-a0a6-58bf0389c5a0                    NaN
#
#                                       foul_committed_card_name
# id
# f158cbc0-a7a1-4787-8f73-15c66ae55764                       NaN
# de5c41c5-9200-439e-b051-bfe2016d689a                       NaN
# 106faebb-00bc-4453-b1c1-1bacdb1ebbc5                       NaN
# 309f6f06-3977-49ac-8c0b-0e31b54404ed                       NaN
# d1c8dbc7-a164-4e34-8674-1eeba842cbbd                       NaN
# 38ac2346-ce1d-4d7a-9dcc-39d337eebede                       NaN
# 7f6c533d-e8d4-4810-8be6-e3183e3caea1                       NaN
# 79e0c6d1-9640-420a-8ba8-d0304b1f24fa                       NaN
# 9a3c4fba-3223-4305-a06b-e08f52796c34                       NaN
# cb2480d3-d896-4568-9fb5-d0a4d1a70ddd                       NaN
# d3c5e620-8fa9-4c0b-8fd8-a6c95463c53b                       NaN
# 300ca316-03cf-4aa1-b12c-68d91ffb6f1e                       NaN
# 9fe6251c-6b05-4f27-bcda-2042f7dce864                       NaN
# 8ea1599d-6dc6-4e00-8d51-2f28f41a3d6f                       NaN
# 9c5e8a81-051b-440b-9aad-dd704587ee30                       NaN
# 435009e3-0653-45e3-95f6-f4215613adab                       NaN
# d68b860f-d159-4a6f-b53f-b49b024c9399                       NaN
# ee3a7d47-de33-4a21-9dc1-927571c52729                       NaN
# 1b0b67f2-c8aa-4286-a0a6-58bf0389c5a0                       NaN
#
# [19 rows x 73 columns]
